# %%
print("hello world q")
# Out:
# hello world q

# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*2
# Out:
# 4

# %%
3/2
# Out:
# 1.5

# %%
50%4
# Out:
# 2

# %%
7/4 mod 2
# Out:
#   Cell In[8], line 1
#     7/4 mod 2
#         ^
# SyntaxError: invalid syntax

# %%
2**3
# Out:
# 8

# %%
2+10*(4-2)
# Out:
# 22

# %%
0.1+0.2-0.3
# Out:
# 5.551115123125783e-17

# %%
from decimal import Decimal
Decimal('0.1') + Decimal('0.2') - Decimal('0.3')  # -> Decimal('0.0')
# Out:
# Decimal('0.0')

# %%
1/2
# Out:
# 0.5

# %%
strsss ="test kar raa hu "

# %%
print (strsss)
# Out:
# test kar raa hu

# %%
type(strsss)
# Out:
# str

# %%
myincome=100
taxrate=.20
mytax=myincome*taxrate
print(mytax)
# Out:
# 20.0

# %%
"I dont't know"
# Out:
# "I dont't know"

# %%
print("hello world q \n" 
      
      "hello wordl2")
# Out:
# hello world q
# hello wordl2

# %%
len( "i and dsd ")
# Out:
# 10

# %%
dd

# %%
name="sam"

# %%
name[0]="P"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 name[0]="P"
#
# TypeError: 'str' object does not support item assignment

# %%
x='Hello World '
x.upper()
# Out:
# 'HELLO WORLD '

# %%
x.lower()
# Out:
# 'hello world '

# %%
x.split()
# Out:
# ['Hello', 'World']

# %%
x.split?
# Out:
# Signature: x.split(sep=None, maxsplit=-1)
# Docstring:
# Return a list of the substrings in the string, using sep as the separator string.
#
#   sep
#     The separator used to split the string.
#
#     When set to None (the default value), will split on any whitespace
#     character (including \n \r \t \f and spaces) and will discard
#     empty strings from the result.
#   maxsplit
#     Maximum number of splits.
#     -1 (the default value) means no limit.
#
# Splitting starts at the front of the string and works to the end.
#
# Note, str.split() is mainly useful for data that has been intentionally
# delimited.  With natural text that includes punctuation, consider using
# the regular expression module.
# Type:      builtin_function_or_method

# %%
x.split('o')
# Out:
# ['Hell', ' W', 'rld ']

# %%
myname='Hose'

print(myname + ' is my name')
# Out:
# Hose is my name

# %%
"hello {} how are you".format("sam")
# Out:
# 'hello sam how are you'

# %%
r=10000/2
"{r1:1.5f}".format(r1=r)
# Out:
# '5000.00000'

# %%
 
      print("Python {}!".format('rules'))   
# TODO: write code...
# Out:
#   Cell In[10], line 1
#     print("Python {}!".format('rules'))
#     ^
# IndentationError: unexpected indent

# %%
mylist=['z','a','b','c','d']

mylist.sort()

# %%
mylist
# Out:
# ['a', 'b', 'c', 'd', 'z']

# %%
newlist=mylist
newlist
# Out:
# ['a', 'b', 'c', 'd', 'z']

# %%
mylist.append('e')
mylist
# Out:
# ['a', 'b', 'c', 'd', 'z', 'e', 'e']

# %%
newlist
# Out:
# ['a', 'b', 'c', 'd', 'z', 'e', 'e']

# %%
mydict={'name':'sam','age':['1.3','h'],'city':'chicago'}

mydict['age'][0]
# Out:
# '1.3'

# %%
mydict['age'][1].upper()
# Out:
# 'H'

# %%
mydict['f']='hello'

# %%
mydict
# Out:
# {'name': 'sam', 'age': ['1.3', 'h'], 'city': 'chicago', 'f': 'hello'}

# %%
dict={'a':'b','c':'d','a':'f'}

# %%
dict['a']
# Out:
# 'f'

# %%
t=(1,23,4,' 233')

# %%
t
# Out:
# (1, 23, 4, ' 233')

# %%
t.len

# %%
my_list = [1, 2, 3, 4, 5]
list_length = len(my_list)
print(f"List length: {list_length}")

# %%
t=set([1,2,3,4,5])

# %%
t
# Out:
# {1, 2, 3, 4, 5}

# %%
t.add(5)

# %%
t.add(5)

# %%
t
# Out:
# {1, 2, 3, 4, 5}

# %%
q=set()
q.add(1)
q.add(2)

# %%
q.add(2)

# %%
set('Missisippi')
# Out:
# {'M', 'i', 'p', 's'}

# %%
w=1>2

# %%
w
# Out:
# False
